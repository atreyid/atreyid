# %% [markdown]
# <a href="https://colab.research.google.com/github/atreyid/atreyid/blob/main/unit_tests_expenses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf75dd5e-568d-4e4c-b5e8-e5b3b18210db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf75dd5e-568d-4e4c-b5e8-e5b3b18210db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Passed_Expense_Encounters_2022_03_24.xlsx to Passed_Expense_Encounters_2022_03_24 (3).xlsx

# %%
pd.set_option('display.max_rows', None)
df = pd.read_excel('Passed_Expense_Encounters_2022_03_24 (3).xlsx', index_col=None)

# %%
df.sample(2)
# Out:
#       index scenario             payerName vehicleCompanyName  \
# 1916    154    Meals  Superior Health Plan     SafeRide Meals
# 1605    243    Meals  Superior Health Plan     SafeRide Meals
#
#                planCode  vehicleCompanyNPI  vehicleCompanyAPI  \
# 1916  Unknown Plan Code                NaN                NaN
# 1605                 KE                NaN                NaN
#
#      vehicleCompanyTaxonomy  vehicleCompanyTaxId         billingProviderMTI  \
# 1916             174200000X          813037449.0  TUnknown Plan Code0003687
# 1605             174200000X          813037449.0                 TKE0003687
#
#       ... fromZipcode               toAddress1       toCity toState  \
# 1916  ...         NaN  4410 MEDICAL DR STE 610  SAN ANTONIO      TX
# 1605  ...         NaN           6701 FANNIN ST      HOUSTON      TX
#
#       toZipcode finalCost payingICN units pickupDate.1  attendants
# 1916      78229      75.0       NaN   4.0     20220223           3
# ...

# %% [markdown]
# Everything str, 4 dates -
# df['pickupDate'] = pd.to_datetime(df['pickupDate'].astype(str))
# df['claimReceiptDate'] = pd.to_datetime(df['claimReceiptDate'].astype(str))
# df['claimAdjudicationDate'] = pd.to_datetime(df['claimAdjudicationDate'].astype(str))
# df['claimPaymentDate'] = pd.to_datetime(df['claimPaymentDate'].astype(str))

# %%
sorted(df.columns)
# Out:
# ['Frequency',
#  'OtherEventIndicator',
#  'SharedServicesRefID',
#  'VIN',
#  'appointmentDate',
#  'attendants',
#  'authorizationNumber1',
#  'authorizationNumber2',
#  'billingAddress',
#  'billingAddress2',
#  'billingCity',
#  'billingPayToAddress',
#  'billingPayToAddress2',
#  'billingPayToCity',
#  'billingPayToState',
#  'billingPayToZip',
#  'billingProviderMTI',
#  'billingState',
#  'billingZip',
#  'careProviderAddress',
#  'careProviderCity',
#  'careProviderNPI',
#  'careProviderName',
#  'careProviderState',
#  'careProviderTPI',
#  'careProviderTaxId',
#  'careProviderTaxonomy',
#  'careProviderZipcode',
#  'claimAdjudicationDate',
#  'claimPaymentDate',
#  'claimReceiptDate',
#  'driverFirstname',
#  'driverLastName',
#  'driverLicense',
#  'driverMTI',
#  'driverSSN',
#  'dropoffCountyCode',
#  'finalCost',
#  'fromAddress1',
#  'fromCity',
#  'fromState',
#  'fromZipcode',
#  'index',
#  'insuredAddress',
#  'insuredAddress2',
#  'insuredCity',
#  'insuredDOB',
# ...

# %%
df['scenario'].unique()
# Out:
# array(['Meals', 'Airfare', 'Lodging', 'Bus', 'ITP - Other'], dtype=object)

# %%
df.shape
# Out:
# (3543, 90)

# %% [markdown]
# # Unit Tests

# %% [markdown]
# #### 38 Lodging units cannot exceed 7 days per encounter.

# %%
#"Lodging units cannot exceed 7 days per encounter.	"
def chk_lodging_units(df):
  counter = 0
  for index, row in df.iterrows():
    if row['scenario'] == 'Lodging':
      if row['units'] > 7:
        counter +=1
  if counter > 0:
    return False
  return True

# %%
chk_lodging_units(df)
# Out:
# True

# %% [markdown]
# #### 41 Mileage reimbursement to ITPs must equal the MTP allowed amount.

# %%
def chk_final_cost(df):
  counter = 0
  for index, row in df.iterrows():
    if row['scenario'].startswith('ITP'):
      if round(row['finalCost']/row['units'],2) != 0.56:
        counter +=1
  if counter > 0:
    print("Number of rows that did not pass the chk_final_cost_test are:", counter)
    return False
  return True

# %%
chk_final_cost(df)
# Out:
# True

# %%
df['pickupDate'] = pd.to_datetime(df['pickupDate'].astype(str))
df['claimReceiptDate'] = pd.to_datetime(df['claimReceiptDate'].astype(str))
df['claimAdjudicationDate'] = pd.to_datetime(df['claimAdjudicationDate'].astype(str))
df['claimPaymentDate'] = pd.to_datetime(df['claimPaymentDate'].astype(str))

# %%
def chk_payment_method_7(df):
  counter = 0
  for index, row in df.iterrows():
    if row['paymentMethod'] == 'AF' or row['paymentMethod'] == 'CC':
      if row['pickupDate'] > row['claimReceiptDate']:
        counter +=1
  if counter > 0:
    print("Number of rows that did not pass the chk_payment_method are:", counter)
    return False
  return True

# %%
chk_payment_method(df)
# Out:
# True

# %%
def chk_payment_method_44(df):
  counter = 0
  for index, row in df.iterrows():
    if row['pickupDate'] > row['claimReceiptDate']:
      if row['paymentMethod'] != 'AF' or row['paymentMethod'] != 'CC':
        counter +=1
  if counter > 0:
    print("Number of rows that did not pass the chk_payment_method_44 are:", counter)
    return False
  return True

# %%
chk_payment_method_44(df)
# Out:
# True

# %%
#check claim receipt date exists
def is_claimReceiptDate(df):
  counter = 0
  for index, row in df.iterrows():
    if row['claimReceiptDate']:
      pass
    else:
      counter +=1
  if counter > 0:
    print("Number of rows that did not pass the is_claimReceiptDate are:", counter)
    return False
  return True

# %%
is_claimReceiptDate(df)
# Out:
# True

# %%
#check claim adjugation date exists
def is_claimAdjudicationDate(df):
  counter = 0
  for index, row in df.iterrows():
    if row['claimAdjudicationDate']:
      pass
    else:
      counter +=1
  if counter > 0:
    print("Number of rows that did not pass the is_claimAdjudicationDate are:", counter)
    return False
  return True

# %%
is_claimAdjudicationDate(df)
# Out:
# True

# %%
def chk_claim_adjugation_date_27(df):
  counter = 0
  for index, row in df.iterrows():
    if (
        row['claimAdjudicationDate'] == row['claimReceiptDate'] or 
        row['claimAdjudicationDate'] > row['claimReceiptDate']
    ):
      pass
    else:
      counter += 1
  if counter > 0:
    print("Number of rows that did not pass the chk_claim_adjugation_date_27 are:", counter)
    return False
  return True

# %%
chk_claim_adjugation_date_27(df)
# Out:
# True

# %%
#Claim payment date is a valid date
def is_claimPaymentDate(df):
  counter = 0
  for index, row in df.iterrows():
    if row['claimPaymentDate']:
      pass
    else:
      counter +=1
  if counter > 0:
    print("Number of rows that did not pass the is_claimPaymentDate are:", counter)
    return False
  return True

# %%
is_claimPaymentDate(df)
# Out:
# True

# %%
def chk_claim_payment_date_48(df):
  counter = 0
  for index, row in df.iterrows():
    if (
        row['claimPaymentDate'] == row['claimReceiptDate'] or 
        row['claimPaymentDate'] > row['claimReceiptDate']
    ):
      pass
    else:
      counter += 1
  if counter > 0:
    print("Number of rows that did not pass the chk_claim_payment_date_48 are:", counter)
    return False
  return True

# %%
chk_claim_payment_date_48(df)
# Out:
# True

# %%
df['scenario'].unique()
# Out:
# array(['Meals', 'Airfare', 'Lodging', 'Bus', 'ITP - Other'], dtype=object)

# %%
selected_cols = ['index', 'scenario', 'payerName', 'vehicleCompanyName', 'planCode',
       'vehicleCompanyTaxonomy',
       'vehicleCompanyTaxId', 'billingProviderMTI', 'billingAddress',
       'billingAddress2', 'billingCity', 'billingState', 'billingZip',
       'billingPayToAddress', 'billingPayToAddress2', 'billingPayToCity',
       'billingPayToState', 'billingPayToZip', 'procCode', 'careProviderName',
       'careProviderTPI', 'careProviderNPI', 'careProviderTaxonomy',
       'careProviderTaxId', 'careProviderAddress', 'careProviderCity',
       'careProviderState', 'careProviderZipcode',
       'patientMedicalId', 'insuredLast', 'insuredFirst','insuredAddress2', 
       'insuredCity', 'insuredState',
       'insuredZip', 'insuredDOB', 'insuredSex', 'patLast', 'patFirst',
       'patientAddress', 'patientAddress2', 'patientCity', 'patientState',
       'patientZip', 'patDOB', 'patSex', 'pickupDate', 'appointmentDate',
       'authorizationNumber1', 'Frequency',
       'claimReceiptDate', 'claimAdjudicationDate', 'memberCountyCode',
       'pickupCountyCode', 'dropoffCountyCode', 'specialNeeds1',
       'specialNeeds2', 'specialNeeds3', 'specialNeeds4', 'paymentMethod',
       'SharedServicesRefID', 'claimPaymentDate', 'lessThan48Hour',
       'riskGroup', 'tripVerified', 'toAddress1', 'toCity',
       'toState', 'toZipcode', 'finalCost',  'units',
       'pickupDate.1']

# %%
df_meals_and_lodging = df[(df['scenario'] == 'Meals') | (df['scenario'] == 'Lodging')]

# %%
is_na_cols = pd.DataFrame(df_meals_and_lodging.isna().sum())

# %%
is_na_cols.reset_index(inplace = True)

# %%
is_na_cols.columns = ['Column_Names', 'Count']

# %%
all_cols = is_na_cols['Column_Names']

# %%
is_na_cols
# Out:
#               Column_Names  Count
# 0                    index      0
# 1                 scenario      0
# 2                payerName      0
# 3       vehicleCompanyName      0
# 4                 planCode      0
# 5        vehicleCompanyNPI   2823
# 6        vehicleCompanyAPI   2823
# 7   vehicleCompanyTaxonomy      0
# 8      vehicleCompanyTaxId      0
# 9       billingProviderMTI      0
# 10          billingAddress      0
# 11         billingAddress2      0
# 12             billingCity      0
# 13            billingState      0
# 14              billingZip      0
# 15     billingPayToAddress      0
# 16    billingPayToAddress2      0
# 17        billingPayToCity      0
# 18       billingPayToState      0
# 19         billingPayToZip      0
# 20                procCode      0
# 21        careProviderName      0
# 22         careProviderTPI      0
# 23         careProviderNPI      0
# 24    careProviderTaxonomy      0
# 25       careProviderTaxId    929
# ...

# %%
df['patSex'].unique()
# Out:
# array([nan, 'M', 'F'], dtype=object)

# %%
for index,row in df.iterrows():
  if row['insuredSex'] == 'nan':
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15       True
# 16       True
# 17       True
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44       True
# 45       True
# 46       True
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55       True
# 56       True
# 57       True
# 58       True
# 59       True
# 60       True
# 61      False
# ...

# %%
#Check for all conditions
def check_all():
  num_of_valid_rows = 0

  if chk_final_cost(df) and chk_final_cost(df):
      num_of_valid_rows += 1
  print(num_of_valid_rows)
  num_of_invalid_rows = df.shape[0] - num_of_valid_rows
  return num_of_invalid_rows

# %%
check_all()
# Out:
# Number of rows that did not pass the chk_final_cost_test are: 547
# 0
# 3543

# %%
#"Lodging units cannot exceed 7 days per encounter.	"

if 'scenario - B' = Lodging then 'units - CJ' cannot be > 7
